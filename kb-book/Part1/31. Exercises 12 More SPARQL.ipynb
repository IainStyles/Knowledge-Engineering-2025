# %% [markdown]
# # Exercises 12: More SPARQL

# %% [markdown]
# 1. Load in the ontology `teaching.rdf` and
#
# a) Write a query using the OWLReady2 search capability to find all entities to which the entity with attribute `program_title="MSc Artificial Intelligence` has a direct relation (in either direction). Plot the resulting network.

# %%
# Placeholder for code

# %% [markdown]
#     b) Repeat part (a) using SPARQL.

# %%
# Placeholder for code

# %% [markdown]
# 2. Load in the ontology `HALD.rdf`.
#
# a) Write a query to extract the 1- and 2- neighbourhoods of the `Disease` entity "Prostatic Neoplasms" and plot the graph. You may use with SPARQL or OWLReady2's `search` function for this.

# %%
# Placeholder for code

# %% [markdown]
# b) By systemtically growing size of the neighbourhood, find a pathway from "Prostatic Neoplasms" to "Prostatis" (hint: based on the names, do you expect these to be near or far apart?)

# %%
# Placeholder for code
