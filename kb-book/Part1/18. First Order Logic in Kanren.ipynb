# %% [markdown]
# # First Order Logic in Kanren

# %% [markdown]
# In propositional logic, we typically have a very simple mapping between propositions and logic variables: one variable per proposition. In first order logic, this is not so simple because of the variables and quantifiers. As we know, first order logic requires us to provide an interpretation, which means we cannot treat first order logic in the same abstract way that we treated propositional logic. In particular, we will need to:
#
# * Define the predicates.
# * Specify what values our variables can take.
# * Define the quantifier.
#
# Let's consider a simple problem, express it in first order logic, and then write a Kanren program to solve it.
#
# Anjali, Brian, and Chen graduated from QUB on different days this summer. One of them studied French, one studied Geography, one read History. One scored a good 60%, one acheived a very good 65%, and the other an excellent 70%.
#
# We have acquired some knowledge about who studied what and what their marks were. However, our knowledge is incomplete. Here is what we know:
#
# 1. The person who studied French scored 65%.
# 2. Anjali studied Geography.
# 3. Brian's mark was 60%.
#
# Let's express this in first order logic. We will define a predicate $P(n,s,m)$ over variables $n\in\{Anjali, Brian, Chen\}$, $s\in\{French, Geography, History\}$, $m\in\{60\%,65\%,70\%\}$. Our three pieces of knowledge become:

# %% [markdown]
# - $(\exists n): [P(n,French,65\%)]$
# - $(\exists m): [P(Anjali,Geography,m)]$
# - $(\exists s): [P(Brian,s,60\%)]$

# %% [markdown]
# We also know that $Chen$, $History$, and $70\%$ need to be somewhere in the solution:

# %% [markdown]
# - $(\exists s)(\exists m): [Chen,s,m)]$
# - $(\exists n)(\exists m): [P(n,History,m)]$
# - $)\exists n)(\exists s): [P(n,s,70\%)]$

# %% [markdown]
# Finally, we also know that each possible solution needs to contain three items (one corresponding to each person). This is implicit knowledge that we naturally use; here we will have to explicitly specify it to prevent uncontrolled trivial solutions with free variables.
#
# We now have to write goals that embody our knowledge. How do we go about this?
#
# * The predicate $P$ takes three quantifiers. We will therefore model the solution as a *list of triples*, each member of which contains values of the variable that satisfy the goals. Thus, each member of that list must be a triple.
# * Each piece of knowledge must be present (ie `membero`) in the solution.
#
# This is enough for us to build a set of goals:

# %%
from kanren import run, var, membero, eq, lall, lany

graduations = var()

goals = lall(
    eq((var(),var(),var()),graduations),
    membero((var(), "French", "65%"), graduations),
    membero(("Anjali", "Geography", var()), graduations),
    membero(("Brian", var(), "60"), graduations),
    membero((var(), var(), "70"), graduations),
    membero(("Chen", var(), var()), graduations),
    membero((var(), "History", var()), graduations),
)

run(1, graduations, rules)
# Out:
# ((('Chen', 'French', '65%'),
#   ('Anjali', 'Geography', '70'),
#   ('Brian', 'History', '60')),)

# %% [markdown]
# Notice that the solution appears six times, once in each possible permutation. We have included nothing in the goals to prevent this and there is no reason to prefer one ordering over another.

# %% [markdown]
# Let's now modify this to include another piece of information:
#
# Anjali, Brian, and Chen graduated from QUB on different days this summer. One of them studied French, one studied Geography, one read History. One scored a good 60%, one acheived a very good 65%, and the other an excellent 70%. One of them graduated on the 2nd July, one graduated on the 3rd July, one graduated on the 4th July.
#
# 1. The person who studied French scored 65%.
# 2. Anjali studied Geography.
# 3. Brian's mark was 60%.
# 4. Chen graduated on the day before Anjali.
# 5. Brian graduated on the 4th.
#
# Our existing goals are therefore modified to (for $d\in\{2,3,4\}):

# %% [markdown]
# - $(\exists n)(\exists d): [P(n,French,65,d)]$
# - $(\exists m)(\exists d): [P(Anjali,Geography,m,d)]$
# - $(\exists s)(\exists d): [P(Brian,s,60,d)]$
# - $(\exists s)(\exists m)(\exists d): [Chen,s,m,d)]$
# - $(\exists n)(\exists m)(\exists d): [P(n,History,m,d)]$
# - $(\exists n)(\exists s)(\exists d): [P(n,s,70,d)]$

# %% [markdown]
# To these we add some new goals;

# %% [markdown]
# - $(\exists n)(\exists s): [P(Anjali,s,n,3)]$
# - $(\exists s,s')(\exists m,m')(\exists d): [P(Chen,s,m,d)\land P(Anjali,s',m',d+1)]$
# - $(\exists n)(\exists s)(\exists m): [P(n,s,m,2)]$
# - $(\exists n)(\exists s)(\exists m): [P(n,s,m,3)]$
# - $(\exists n)(\exists s)(\exists m): [P(n,s,m,4)]$

# %% [markdown]
# We can now code these up. We will need to make some adjustments to the rules that we already have to accomodate the additional variable. We will also have to figure out how to deal with the new information that something happened "before" something else.

# %%
def daybefore(x,y,lst):
    return(membero)


goals = lall(
    eq((var(),var(),var(),var()),graduations),
    membero((var(), "French", "65",var()), graduations),
    membero(("Anjali", "Geography", var(),var()), graduations),
    membero(("Brian", var(), "60",var()), graduations),
    membero((var(), var(), "70",var()), graduations),
    membero(("Chen", var(), var(),var()), graduations),
    membero((var(), "History", var(),var()), graduations),
    membero((var(), var(), var(), 2), graduations),
    membero((var(), var(), var(), 3), graduations),
    membero((var(), var(), var(), 4), graduations),
    membero(("Brian", var(), var(), 4), graduations)
    daybefore(("Chen",var(),var(),var()),("Anjali",var(),var(),var()),graduations)
)

run(0, graduations, goals)
# Out:
# ((('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 4),
#   ~_185668),
#  (('Anjali', 'Geography', '70', 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 4),
#   ~_185668),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', ~_185691, ~_185692, 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   (~_185690, ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 3),
#   (~_185690, ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', ~_185688, '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', ~_185688, '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, 'History', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Chen', 'History', ~_185689, 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185691, '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', 'History', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', 'History', '70', 2),
#   ('Brian', ~_185688, '60', 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 4),
#   (~_185675, ~_185676, '70', ~_185677)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   (~_185675, ~_185676, '70', ~_185677)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', ~_185691, '70', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 3),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', ~_185688, ~_185689, 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 2),
#   ('Chen', ~_185688, ~_185689, 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, 'History', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'History', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Chen', 'History', ~_185686, 2),
#   ('Brian', ~_185688, '60', 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', 'History', ~_185686, 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  ((~_185684, 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Chen', 'History', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185684, 'History', '70', 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185684, 'History', '70', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, 'French', '65', 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, ~_185691, '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'History', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'History', '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'History', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  ((~_185684, 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Chen', 'History', ~_185689, 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185684, 'History', ~_185686, 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185684, 'History', ~_185686, 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   (~_185681, 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 4),
#   (~_185681, 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185692, 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   (~_185690, 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 3),
#   (~_185690, 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Chen', ~_185688, ~_185689, 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185685, '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', ~_185685, '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', ~_185685, '70', 2),
#   ('Brian', 'History', '60', 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', ~_185685, '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185691, '60', 4),
#   (~_185681, 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   (~_185681, 'History', '70', ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'History', '70', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   (~_185690, 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 3),
#   (~_185690, 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', ~_185689, 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', ~_185689, 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, ~_185691, '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', ~_185688, '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Chen', ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185690, 'History', ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  ((~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Chen', ~_185688, '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185684, ~_185685, '70', 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185684, ~_185685, '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, 'French', '65', 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185690, 'History', '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', ~_185691, '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', ~_185691, '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  ((~_185684, ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185684, 'French', '65', 2),
#   ('Chen', ~_185688, ~_185689, 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185684, ~_185685, ~_185686, 2),
#   ('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185684, ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ~_185668),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 4),
#   ~_185668),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', ~_185691, ~_185692, 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', ~_185685, '70', 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, 'History', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185686, 2),
#   (~_185690, 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   (~_185684, 'History', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   (~_185675, ~_185676, '70', ~_185677)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 4),
#   (~_185675, ~_185676, '70', ~_185677)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', ~_185691, '70', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, 'History', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'History', '70', 2),
#   (~_185690, 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'History', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'History', ~_185689, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   (~_185684, 'History', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', 'History', ~_185689, 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', 'History', ~_185689, 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', 'History', ~_185689, 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', ~_185678, ~_185679, ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', 'History', '60', 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   (~_185684, ~_185685, '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'History', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', 'History', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, 'History', ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, 'History', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'History', '70', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', 'History', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Anjali', 'History', '70', 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Anjali', 'History', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Anjali', 'History', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, ~_185691, '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', ~_185678, '70', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', 'History', '60', 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 3),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'History', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', 'History', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'History', '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'History', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'History', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', 'History', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Anjali', 'History', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Anjali', 'History', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Anjali', 'History', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   (~_185681, 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 4),
#   (~_185681, 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', ~_185692, 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'History', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', '70', 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   (~_185690, 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', ~_185688, '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   (~_185684, ~_185685, '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', ~_185688, '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', ~_185688, '70', 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', ~_185688, '70', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   (~_185681, 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 4),
#   (~_185681, 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', '70', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'History', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'History', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', ~_185686, 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   ('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   (~_185690, ~_185691, '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', ~_185685, '70', 2),
#   (~_185690, 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', ~_185685, '70', 2),
#   ('Brian', 'History', '60', 4),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', ~_185688, ~_185689, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', ~_185688, ~_185689, 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', ~_185688, ~_185689, 3),
#   ('Brian', 'History', '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', ~_185688, ~_185689, 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'History', ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', ~_185688, '60', 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185688, '60', 3),
#   (~_185684, 'History', '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 3),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', ~_185693, '70', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', ~_185693, '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', ~_185693, '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', ~_185685, '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Anjali', ~_185693, '70', 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Anjali', ~_185693, '70', 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Anjali', ~_185693, '70', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'French', '65', 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185690, 'History', '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Anjali', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', ~_185688, '60', 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185688, '60', 3),
#   (~_185684, 'History', ~_185686, 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', ~_185691, '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'French', '65', 2),
#   ('Chen', ~_185691, '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, ~_185685, '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, ~_185685, '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', ~_185693, ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', ~_185693, ~_185694, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', ~_185693, ~_185694, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'French', '65', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Anjali', ~_185693, ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Anjali', ~_185693, ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Anjali', ~_185693, ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', 2),
#   ~_185668),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', 2),
#   ~_185668),
#  (('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 4),
#   ('Chen', ~_185685, ~_185686, 2),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 4),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 4),
#   (~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 4),
#   (~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', ~_185691, '70', 4),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 3),
#   ('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 4),
#   (~_185684, 'History', ~_185686, 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185692, 4),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185692, 4),
#   ('Brian', ~_185685, '60', 2),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 3),
#   (~_185690, 'History', '70', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 3),
#   (~_185690, 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 3),
#   ('Brian', ~_185691, '60', 4),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
# ...
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Chen', 'History', ~_185689, 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, ~_185694, 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   (~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185691, '70', 4),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185691, '70', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   (~_185684, ~_185685, '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', ~_185691, '70', 4),
#   (~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', ~_185691, '70', 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', ~_185691, '70', 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'History', '70', 3)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', 2),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'History', '70', 3)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'History', '70', 3)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', '70', 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185681, 'History', '70', ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185681, 'History', '70', ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'History', '70', 3)),
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Chen', 'History', '70', 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Brian', ~_185691, '60', 4),
#   ('Chen', 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, '70', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', ~_185685, '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', ~_185685, '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185691, ~_185692, 4),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  (('Chen', ~_185691, ~_185692, 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', ~_185691, ~_185692, 4),
#   (~_185684, 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Chen', ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', ~_185677)),
#  (('Chen', ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185690, 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', ~_185682, ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185690, 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'French', '65', 2),
#   ('Chen', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'History', '70', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'History', '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185690, 'French', '65', 4),
#   ('Chen', ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', ~_185683)),
#  ((~_185690, ~_185691, '70', 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', ~_185683)),
#  ((~_185690, 'French', '65', 4),
#   ('Chen', ~_185685, '70', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185690, ~_185691, '70', 4),
#   ('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185690, ~_185691, '70', 4),
#   ('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  ((~_185690, ~_185691, '70', 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'History', '70', 3),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185690, 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3),
#   ('Chen', 'History', '70', ~_185683)),
#  (('Brian', ~_185691, '60', 4),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'History', '70', 3),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185690, 'French', '65', 4),
#   ('Brian', ~_185685, '60', 2),
#   ('Chen', 'History', ~_185689, 3),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'French', '65', 2),
#   ('Chen', 'History', ~_185689, 3),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'History', ~_185686, 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', ~_185691, '60', 4),
#   (~_185684, 'History', ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', ~_185680)),
#  ((~_185690, 'French', '65', 4),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  ((~_185690, ~_185691, ~_185692, 4),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', ~_185683)),
#  ((~_185690, 'French', '65', 4),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185690, ~_185691, ~_185692, 4),
#   ('Chen', 'French', '65', 2),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185690, ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', 2),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 3)),
#  ((~_185690, ~_185691, ~_185692, 4),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', ~_185680)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', 'History', '60', 2),
#   ~_185668),
#  (('Anjali', 'Geography', '70', 4),
#   ('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Brian', 'History', '60', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', ~_185693, ~_185694, 3)),
#  (('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', 'French', '65', 2),
#   ~_185668),
#  (('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', '70', 3),
#   ('Chen', ~_185685, ~_185686, 2),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', 3),
#   (~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', 3),
#   (~_185684, ~_185685, '70', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', ~_185688, '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', ~_185688, '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185684, 'History', ~_185686, 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', '70', 4),
#   ('Chen', 'History', ~_185689, 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'History', '70', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', '70', 4),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', '70', 4),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'History', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', 'History', '70', 4),
#   ('Anjali', 'French', '65', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'Geography', ~_185671, ~_185672)),
#  (('Chen', 'History', '70', 4),
#   ('Brian', ~_185688, '60', 3),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', ~_185694, 3)),
#  (('Chen', 'History', '70', 4),
#   ('Brian', ~_185688, '60', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Brian', 'History', '60', 2),
#   (~_185675, ~_185676, '70', ~_185677)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'French', '65', 3),
#   ('Brian', 'History', '60', 2),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', 'History', '60', 3),
#   ('Chen', 'French', '65', 2),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Brian', 'History', '60', 3),
#   ('Chen', ~_185685, '70', 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', 3),
#   ('Anjali', 'Geography', ~_185686, 2),
#   ('Anjali', ~_185693, '70', 3)),
#  (('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', 'French', '65', 2),
#   (~_185675, ~_185676, '70', ~_185677)),
#  (('Brian', 'History', '60', 4),
#   ('Anjali', 'Geography', ~_185694, 3),
#   ('Chen', ~_185685, '70', 2),
#   (~_185669, 'French', '65', ~_185670)),
#  (('Chen', 'French', '65', 4),
#   ('Brian', 'History', '60', 3),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', 'French', '65', 3),
#   (~_185684, ~_185685, ~_185686, 2),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', ~_185688, ~_185689, 3),
#   (~_185684, 'French', '65', 2),
#   ('Anjali', 'Geography', '70', 3)),
#  (('Brian', 'History', '60', 4),
#   ('Chen', ~_185688, ~_185689, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'Geography', ~_185694, 3),
#   (~_185684, 'History', '70', 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Anjali', 'Geography', ~_185692, 4),
#   ('Chen', 'History', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   ('Anjali', 'French', '65', 3)),
#  (('Chen', 'French', '65', 4),
#   ('Anjali', 'History', ~_185694, 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'French', '65', 3),
#   ('Anjali', 'Geography', '70', 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3),
#   (~_185684, 'French', '65', 2),
#   ('Brian', ~_185673, '60', ~_185674)),
#  (('Chen', 'History', ~_185692, 4),
#   ('Anjali', 'Geography', '70', 3),
#   ('Brian', ~_185685, '60', 2),
#   (~_185669, 'French', '65', ~_185670)),
#  ...)

# %% [markdown]
# Finally, let us consider a variant of this problem where we have a negative constraint:
# 1. The person who studied French scored 65%.
# 2. Anjali studied Geography.
# 3. Brian's mark was 60%.
# 4. Chen graduated on the day before Anjali.
# 5. Anjali did not graduate on the 4th.
#
# Kanren does not provide us with a negation operation. There are sound technical reasons for this. Briefly, the "easy" way to implement this is so-called *negation by failure*. This is essentially the idea that if you can't prove a statement to be true then it must be false. This works for propositional logic but is unable to resolve values of variables in first order logic. There are techniques available for *constructive negation*, but these are all super-exponential in time complexity. This means that some creativity is necessary. Here, we adopt the rather crude method of constructing a positive goal by excluding the desired negative goal. This method is not viable for very large problems.
