# %% [markdown]
# # Exercise 21 - Exact Inference
#
# Given the factorised distribution, compute the following distributions. Verify your calculations against the joint distribution.
#
# 1. $P(F)$
# 2. $P(F,M)$
# 3. $P(M\vert F)$

# %%
# Placeholder
